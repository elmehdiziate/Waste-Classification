# %% [markdown]
# # 1: Imports & Root Detection

# %%
import sys, time
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from sklearn.metrics import (
    confusion_matrix, f1_score, precision_score, recall_score
)

# Notebook‑safe project root detection
root = Path.cwd()
while not (root / "Pipeline_").exists() and root != root.parent:
    root = root.parent

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

print("Project root:", root)

# Import old 224px pipeline
from Pipeline_.preprocessor import WaRPPreprocessor
from Models.ConvNeXT import ConvNeXT

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)
# Out:
# Project root: c:\repo\Waste-Classification
# Device: cuda

# %% [markdown]
# # 2: Hyperparameters (Baseline)

# %%
# ============================
# ConvNeXt Baseline (224px)
# Hyperparameters
# ============================

EPOCHS       = 40          # Baseline = 40 epochs
BATCH_SIZE   = 32
LR           = 1e-4
WEIGHT_DECAY = 1e-4
DROPOUT      = 0.4
HEAD_DEPTH   = 1           # Baseline head depth
NUM_CLASSES  = 28

print("Epochs      :", EPOCHS)
print("Batch size  :", BATCH_SIZE)
print("LR          :", LR)
print("Dropout     :", DROPOUT)
print("Head depth  :", HEAD_DEPTH)
print("Num classes :", NUM_CLASSES)
# Out:
# Epochs      : 40
# Batch size  : 32
# LR          : 0.0001
# Dropout     : 0.4
# Head depth  : 1
# Num classes : 28

# %% [markdown]
# # 3: Data Pipeline (Old 224px Preprocessor)
# ConvNeXt in the old preprocessor uses:
# strong transformer augmentation
# minority augmentation
# MixUp ON
# WeightedRandomSampler

# %%
pp = WaRPPreprocessor(
    raw_root       = root / "Dataset/raw/Warp-C",
    processed_root = root / "Dataset/processed",
    stats_file     = root / "Dataset/dataset_stats.json",
    batch_size     = BATCH_SIZE,
    num_workers    = 4,
)

train_loader, test_loader = pp.get_loaders(model_type="convnext")

CLASS_NAMES = sorted(
    d.name for d in (root / "Dataset/processed/train").iterdir() if d.is_dir()
)

print(f"Classes       : {len(CLASS_NAMES)}")
print(f"Train batches : {len(train_loader)}")
print(f"Test  batches : {len(test_loader)}")
# Out:
# [get_loaders] model='convnext'
#   sampler=True  minority_aug=True  mixup=True  pipeline='transformer'
#   train=273 batches  test=49 batches  sampler=WeightedRandom
# Classes       : 28
# Train batches : 273
# Test  batches : 49

# %% [markdown]
# # 4: Loss, Model, Optimizer

# %%
class_weights = pp.get_class_weights(device=DEVICE)
criterion = nn.CrossEntropyLoss(weight=class_weights)
print("Loss: CrossEntropyLoss + class weights")

model = ConvNeXT(
    num_classes = NUM_CLASSES,
    dropout     = DROPOUT,
    head_depth  = HEAD_DEPTH,
    freeze      = False
).to(DEVICE)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr           = LR,
    weight_decay = WEIGHT_DECAY,
)

# Sanity check
with torch.no_grad():
    x = torch.zeros(2, 3, 224, 224).to(DEVICE)
    y = model(x)
print("Sanity output:", y.shape)
# Out:
# Loss: CrossEntropyLoss + class weights
# Sanity output: torch.Size([2, 28])

# %% [markdown]
# # 5: Training Loop (MixUp ON, No Scheduler)
# ConvNeXt uses MixUp in the old preprocessor.
# We call the built‑in WaRPPreprocessor.mixup_batch.

# %%
train_losses, train_accs, test_accs = [], [], []
best_acc = 0.0

print(f"Starting {EPOCHS} epochs...\n")

for epoch in range(1, EPOCHS + 1):
    t0 = time.time()
    model.train()
    ep_loss = correct = total = 0

    for imgs, lbls in train_loader:
        imgs, lbls = imgs.to(DEVICE), lbls.to(DEVICE)

        # MixUp using old preprocessor implementation
        imgs, soft_lbls = WaRPPreprocessor.mixup_batch(
            images      = imgs,
            labels      = lbls,
            num_classes = NUM_CLASSES,
            alpha       = 0.4,
        )

        optimizer.zero_grad()
        logits = model(imgs)
        log_p  = torch.nn.functional.log_softmax(logits, dim=1)
        loss   = -(soft_lbls * log_p).sum(dim=1).mean()

        loss.backward()
        optimizer.step()

        ep_loss += loss.item()
        correct += (logits.argmax(1) == lbls).sum().item()
        total   += lbls.size(0)

    train_loss = ep_loss / len(train_loader)
    train_acc  = correct / total * 100

    # Evaluation
    model.eval()
    correct = total = 0
    with torch.no_grad():
        for imgs, lbls in test_loader:
            preds = model(imgs.to(DEVICE)).argmax(1).cpu()
            correct += (preds == lbls).sum().item()
            total   += lbls.size(0)
    test_acc = correct / total * 100

    train_losses.append(train_loss)
    train_accs.append(train_acc)
    test_accs.append(test_acc)

    if test_acc > best_acc:
        best_acc = test_acc
        torch.save(model.state_dict(), root / "Models/weights/convnext_baseline_224.pth")
        flag = " ← best"
    else:
        flag = ""

    print(f"Epoch {epoch:3d}/{EPOCHS} | "
          f"loss={train_loss:.4f} | train={train_acc:.2f}% | "
          f"test={test_acc:.2f}% | best={best_acc:.2f}% | "
          f"{time.time()-t0:.1f}s{flag}")
# Out:
# Starting 40 epochs...
#
# Epoch   1/40 | loss=2.4241 | train=20.38% | test=61.44% | best=61.44% | 108.9s ← best
# Epoch   2/40 | loss=1.7176 | train=31.71% | test=70.92% | best=70.92% | 93.7s ← best
# Epoch   3/40 | loss=1.5846 | train=36.42% | test=72.79% | best=72.79% | 93.7s ← best
# Epoch   4/40 | loss=1.4613 | train=38.62% | test=71.57% | best=72.79% | 94.9s
# Epoch   5/40 | loss=1.3437 | train=41.29% | test=76.47% | best=76.47% | 93.7s ← best
# Epoch   6/40 | loss=1.3419 | train=42.34% | test=75.63% | best=76.47% | 93.4s
# Epoch   7/40 | loss=1.3170 | train=44.30% | test=78.14% | best=78.14% | 93.7s ← best
# Epoch   8/40 | loss=1.2361 | train=44.70% | test=79.17% | best=79.17% | 93.6s ← best
# Epoch   9/40 | loss=1.2044 | train=43.26% | test=80.40% | best=80.40% | 93.6s ← best
# Epoch  10/40 | loss=1.1778 | train=42.27% | test=80.53% | best=80.53% | 93.5s ← best
# Epoch  11/40 | loss=1.1240 | train=50.07% | test=78.08% | best=80.53% | 93.4s
# Epoch  12/40 | loss=1.1652 | train=43.11% | test=80.92% | best=80.92% | 93.6s ← best
# Epoch  13/40 | loss=1.0716 | train=45.99% | test=78.79% | best=80.92% | 93.3s
# Epoch  14/40 | loss=1.1318 | train=46.25% | test=79.95% | best=80.92% | 93.4s
# Epoch  15/40 | loss=1.1782 | train=44.04% | test=77.11% | best=80.92% | 93.3s
# Epoch  16/40 | loss=1.1017 | train=48.28% | test=81.24% | best=81.24% | 93.6s ← best
# Epoch  17/40 | loss=1.1213 | train=49.91% | test=80.21% | best=81.24% | 93.3s
# Epoch  18/40 | loss=1.0034 | train=47.69% | test=78.85% | best=81.24% | 93.3s
# Epoch  19/40 | loss=1.0397 | train=47.37% | test=82.14% | best=82.14% | 93.5s ← best
# Epoch  20/40 | loss=1.0630 | train=48.61% | test=80.59% | best=82.14% | 93.3s
# Epoch  21/40 | loss=1.0201 | train=47.23% | test=81.88% | best=82.14% | 93.4s
# Epoch  22/40 | loss=1.0155 | train=49.43% | test=81.04% | best=82.14% | 93.4s
# Epoch  23/40 | loss=1.0246 | train=49.57% | test=80.59% | best=82.14% | 93.4s
# Epoch  24/40 | loss=0.9990 | train=44.48% | test=80.14% | best=82.14% | 93.4s
# Epoch  25/40 | loss=0.9564 | train=52.15% | test=81.50% | best=82.14% | 93.4s
# Epoch  26/40 | loss=0.9929 | train=45.63% | test=81.56% | best=82.14% | 93.3s
# Epoch  27/40 | loss=1.0581 | train=49.31% | test=80.08% | best=82.14% | 93.4s
# Epoch  28/40 | loss=1.0003 | train=45.83% | test=82.85% | best=82.85% | 93.6s ← best
# Epoch  29/40 | loss=0.9913 | train=44.46% | test=81.75% | best=82.85% | 93.4s
# Epoch  30/40 | loss=0.9157 | train=44.95% | test=81.24% | best=82.85% | 93.4s
# Epoch  31/40 | loss=0.9954 | train=51.03% | test=81.37% | best=82.85% | 93.4s
# Epoch  32/40 | loss=0.9710 | train=53.10% | test=82.27% | best=82.85% | 93.4s
# Epoch  33/40 | loss=0.9326 | train=53.59% | test=82.14% | best=82.85% | 93.4s
# Epoch  34/40 | loss=0.8706 | train=52.43% | test=80.46% | best=82.85% | 93.4s
# Epoch  35/40 | loss=0.9627 | train=50.84% | test=80.40% | best=82.85% | 93.4s
# Epoch  36/40 | loss=0.9340 | train=50.16% | test=80.14% | best=82.85% | 93.4s
# Epoch  37/40 | loss=0.9288 | train=48.39% | test=81.50% | best=82.85% | 93.4s
# Epoch  38/40 | loss=0.8628 | train=49.97% | test=80.53% | best=82.85% | 93.4s
# Epoch  39/40 | loss=0.9367 | train=49.82% | test=80.72% | best=82.85% | 93.4s
# Epoch  40/40 | loss=0.9718 | train=47.52% | test=81.50% | best=82.85% | 93.4s

# %% [markdown]
# # 6: Training Curves

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
ep = range(1, EPOCHS + 1)

axes[0].plot(ep, train_losses, "#1565C0", lw=2)
axes[0].set(title="Training Loss", xlabel="Epoch", ylabel="Loss")
axes[0].grid(alpha=0.3)

axes[1].plot(ep, train_accs, "#2E7D32", lw=2)
axes[1].set(title="Train Accuracy", xlabel="Epoch", ylabel="Accuracy (%)")
axes[1].grid(alpha=0.3)

axes[2].plot(ep, test_accs, "#E65100", lw=2)
axes[2].axhline(max(test_accs), color="red", ls="--", label=f"Best={max(test_accs):.2f}%")
axes[2].set(title="Test Accuracy", xlabel="Epoch", ylabel="Accuracy (%)")
axes[2].legend()
axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 7: Final Evaluation + Confusion Matrix

# %%
WEIGHTS_PATH = root / "Models/weights/convnext_baseline_224.pth"

model.load_state_dict(torch.load(WEIGHTS_PATH, map_location=DEVICE))
model.to(DEVICE)
model.eval()

all_preds, all_labels = [], []

with torch.no_grad():
    for imgs, lbls in test_loader:
        preds = model(imgs.to(DEVICE)).argmax(1).cpu()
        all_preds.extend(preds.numpy())
        all_labels.extend(lbls.numpy())

y_pred = np.array(all_preds)
y_true = np.array(all_labels)

acc  = (y_pred == y_true).mean() * 100
macro_f1   = f1_score(y_true, y_pred, average="macro") * 100
weighted_f1 = f1_score(y_true, y_pred, average="weighted") * 100
prec = precision_score(y_true, y_pred, average="macro") * 100
rec  = recall_score(y_true, y_pred, average="macro") * 100

print("="*50)
print("ConvNeXt Baseline (224px): Final Metrics")
print("="*50)
print(f"Accuracy     : {acc:.2f}%")
print(f"Macro F1     : {macro_f1:.2f}%")
print(f"Weighted F1  : {weighted_f1:.2f}%")
print(f"Precision    : {prec:.2f}%")
print(f"Recall       : {rec:.2f}%")
print("="*50)

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

fig, ax = plt.subplots(figsize=(18, 15))
sns.heatmap(
    cm_norm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES,
    linewidths=0.3
)
ax.set_title(f"ConvNeXt Baseline (224px): Confusion Matrix\nAcc={acc:.2f}%", fontsize=14)
ax.set_xlabel("Predicted")
ax.set_ylabel("True")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# ==================================================
# ConvNeXt Baseline (224px): Final Metrics
# ==================================================
# Accuracy     : 82.85%
# Macro F1     : 80.87%
# Weighted F1  : 82.74%
# Precision    : 81.80%
# Recall       : 81.30%
# ==================================================
