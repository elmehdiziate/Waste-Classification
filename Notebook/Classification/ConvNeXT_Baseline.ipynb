# %% [markdown]
# # 1: Imports & Root Detection

# %%
# import the imports.
import sys, time
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from sklearn.metrics import (confusion_matrix, f1_score, precision_score, recall_score)

root = Path.cwd()
while not (root / "Pipeline_").exists() and root != root.parent:
    root = root.parent

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

print("Project root:", root)


# load preprocessor and model definition.
from Pipeline_.preprocessor import WaRPPreprocessor
from Models.ConvNeXT import ConvNeXT


# GPU is used if available 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)
# Out:
# Project root: c:\repo\Waste-Classification
# Device: cuda

# %% [markdown]
# # 2: Hyperparameters

# %%
EPOCHS          = 100        
BATCH_SIZE      = 32         
LR              = 1e-4       
WEIGHT_DECAY    = 1e-4       
DROPOUT         = 0.4        
HEAD_DEPTH      = 1          
NUM_CLASSES     = 28         
NUM_WORKERS     = 4           

print("Epochs      :", EPOCHS)
print("Batch size  :", BATCH_SIZE)
print("LR          :", LR)
print("Dropout     :", DROPOUT)
print("Head depth  :", HEAD_DEPTH)
print("Num classes :", NUM_CLASSES)
print("Num workers :", NUM_WORKERS)
# Out:
# Epochs      : 100
# Batch size  : 32
# LR          : 0.0001
# Dropout     : 0.4
# Head depth  : 1
# Num classes : 28
# Num workers : 4

# %% [markdown]
# # 3: Data Pipeline
# ConvNeXt in the preprocessor uses:
# strong transformer augmentation
# minority augmentation
# MixUp ON
# WeightedRandomSampler

# %%
# init pre-processor 
pp = WaRPPreprocessor(
    raw_root       = root / "Dataset/raw/Warp-C",           
    processed_root = root / "Dataset/processed",            
    stats_file     = root / "Dataset/dataset_stats.json",   
    batch_size     = BATCH_SIZE,                            
    num_workers    = NUM_WORKERS                             
)

train_loader, test_loader = pp.get_loaders(model_type="convnext")

CLASS_NAMES = sorted(d.name for d in (root / "Dataset/processed/train").iterdir() if d.is_dir())

print(f"Classes       : {len(CLASS_NAMES)}")
print(f"Train batches : {len(train_loader)}")
print(f"Test  batches : {len(test_loader)}")
# Out:
# [get_loaders] model='convnext'
#   sampler=True  minority_aug=True  mixup=True  pipeline='transformer'
#   train=273 batches  test=49 batches  sampler=WeightedRandom
# Classes       : 28
# Train batches : 273
# Test  batches : 49

# %% [markdown]
# # 4: Loss, Model, Optimizer

# %%
# weighted cross-entropy 
class_weights = pp.get_class_weights(device=DEVICE)

# cross-entropy loss 
criterion = nn.CrossEntropyLoss(weight=class_weights)
print("Loss: CrossEntropyLoss + class weights")

# Instantiate ConvNeXT as defined in the ConvNeXT.py file.
# freeze == false ensure backbone layers are trainable for a full fine-tuning setup.
model = ConvNeXT(num_classes = NUM_CLASSES, dropout = DROPOUT, head_depth = HEAD_DEPTH, freeze = False).to(DEVICE)

optimizer = torch.optim.AdamW(model.parameters(), lr = LR, weight_decay = WEIGHT_DECAY)

with torch.no_grad():                           
    x = torch.zeros(2, 3, 224, 224).to(DEVICE)  
    y = model(x)                                
print("Sanity output:", y.shape)
# Out:
# Loss: CrossEntropyLoss + class weights
# Sanity output: torch.Size([2, 28])

# %% [markdown]
# # 5: Training Loop (MixUp ON, No Scheduler)
# ConvNeXt uses MixUp in the old preprocessor.
# We call the built‑in WaRPPreprocessor.mixup_batch.

# %%
# save training loss & accuracy, and test accuracy.
train_losses, train_accs, test_accs = [], [], []

# Hold best current accuracy 
best_acc = 0.0

# Path to save the best model checkpoint
WEIGHTS_PATH = root / "Models/weights/convnext_baseline_224.pth"

print(f"Starting {EPOCHS} epochs...\n")

# main training loop.
for epoch in range(1, EPOCHS + 1):
    t0 = time.time()
    model.train() #set training mode (use dropout, batch norm, layer norm)
    ep_loss = correct = total = 0 # reset batch metrics

    for imgs, lbls in train_loader:
        imgs, lbls = imgs.to(DEVICE), lbls.to(DEVICE)

        # mixUp augmentation 
        imgs, soft_lbls = WaRPPreprocessor.mixup_batch(images = imgs, labels = lbls, num_classes = NUM_CLASSES, alpha = 0.4)

        optimizer.zero_grad()                                   
        logits = model(imgs)                                    
        log_p  = torch.nn.functional.log_softmax(logits, dim=1) 
        loss   = -(soft_lbls * log_p).sum(dim=1).mean()         
        loss.backward()                                         
        optimizer.step()                                        

        # batch metrics (accumulated) 
        ep_loss += loss.item()
        correct += (logits.argmax(1) == lbls).sum().item()
        total   += lbls.size(0)

    # Computer accuracy and loss 
    train_loss = ep_loss / len(train_loader)
    train_acc  = correct / total * 100

    # Evaluation here (no gradient updates)
    model.eval()                                            
    correct = total = 0                                     
    with torch.no_grad():                                    
        for imgs, lbls in test_loader:                      
            preds = model(imgs.to(DEVICE)).argmax(1).cpu()  
            correct += (preds == lbls).sum().item()         
            total   += lbls.size(0)                         
    test_acc = correct / total * 100                        
    # save metrics, used for plotting.
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    test_accs.append(test_acc)

    # save best model 
    if test_acc > best_acc:
        best_acc = test_acc
        torch.save(model.state_dict(), WEIGHTS_PATH)
        flag = " ← best"
    else:
        flag = ""

    print(f"Epoch {epoch:3d}/{EPOCHS} | "
          f"loss={train_loss:.4f} | train={train_acc:.2f}% | "
          f"test={test_acc:.2f}% | best={best_acc:.2f}% | "
          f"{time.time()-t0:.1f}s{flag}")
# Out:
# Starting 100 epochs...
#
# Epoch   1/100 | loss=2.4241 | train=20.38% | test=61.44% | best=61.44% | 107.8s ← best
# Epoch   2/100 | loss=1.7176 | train=31.71% | test=70.92% | best=70.92% | 92.4s ← best
# Epoch   3/100 | loss=1.5846 | train=36.42% | test=72.79% | best=72.79% | 92.3s ← best
# Epoch   4/100 | loss=1.4613 | train=38.62% | test=71.57% | best=72.79% | 92.2s
# Epoch   5/100 | loss=1.3437 | train=41.29% | test=76.47% | best=76.47% | 93.5s ← best
# Epoch   6/100 | loss=1.3419 | train=42.34% | test=75.63% | best=76.47% | 94.3s
# Epoch   7/100 | loss=1.3170 | train=44.30% | test=78.14% | best=78.14% | 94.5s ← best
# Epoch   8/100 | loss=1.2361 | train=44.70% | test=79.17% | best=79.17% | 94.6s ← best
# Epoch   9/100 | loss=1.2044 | train=43.26% | test=80.40% | best=80.40% | 94.4s ← best
# Epoch  10/100 | loss=1.1778 | train=42.27% | test=80.53% | best=80.53% | 93.4s ← best
# Epoch  11/100 | loss=1.1240 | train=50.07% | test=78.08% | best=80.53% | 94.3s
# Epoch  12/100 | loss=1.1652 | train=43.11% | test=80.92% | best=80.92% | 94.6s ← best
# Epoch  13/100 | loss=1.0716 | train=45.99% | test=78.79% | best=80.92% | 94.3s
# Epoch  14/100 | loss=1.1318 | train=46.25% | test=79.95% | best=80.92% | 94.4s
# Epoch  15/100 | loss=1.1782 | train=44.04% | test=77.11% | best=80.92% | 94.3s
# Epoch  16/100 | loss=1.1017 | train=48.28% | test=81.24% | best=81.24% | 93.4s ← best
# Epoch  17/100 | loss=1.1213 | train=49.91% | test=80.21% | best=81.24% | 92.4s
# Epoch  18/100 | loss=1.0034 | train=47.69% | test=78.85% | best=81.24% | 92.2s
# Epoch  19/100 | loss=1.0397 | train=47.37% | test=82.14% | best=82.14% | 92.4s ← best
# Epoch  20/100 | loss=1.0630 | train=48.61% | test=80.59% | best=82.14% | 92.3s
# Epoch  21/100 | loss=1.0201 | train=47.23% | test=81.88% | best=82.14% | 92.1s
# Epoch  22/100 | loss=1.0155 | train=49.43% | test=81.04% | best=82.14% | 92.1s
# Epoch  23/100 | loss=1.0246 | train=49.57% | test=80.59% | best=82.14% | 92.1s
# Epoch  24/100 | loss=0.9990 | train=44.48% | test=80.14% | best=82.14% | 92.0s
# Epoch  25/100 | loss=0.9564 | train=52.15% | test=81.50% | best=82.14% | 92.0s
# Epoch  26/100 | loss=0.9929 | train=45.63% | test=81.56% | best=82.14% | 92.0s
# Epoch  27/100 | loss=1.0581 | train=49.31% | test=80.08% | best=82.14% | 92.1s
# Epoch  28/100 | loss=1.0003 | train=45.83% | test=82.85% | best=82.85% | 92.3s ← best
# Epoch  29/100 | loss=0.9913 | train=44.46% | test=81.75% | best=82.85% | 92.1s
# Epoch  30/100 | loss=0.9157 | train=44.95% | test=81.24% | best=82.85% | 92.0s
# Epoch  31/100 | loss=0.9954 | train=51.03% | test=81.37% | best=82.85% | 92.1s
# Epoch  32/100 | loss=0.9710 | train=53.10% | test=82.27% | best=82.85% | 92.0s
# Epoch  33/100 | loss=0.9326 | train=53.59% | test=82.14% | best=82.85% | 92.1s
# Epoch  34/100 | loss=0.8706 | train=52.43% | test=80.46% | best=82.85% | 92.0s
# Epoch  35/100 | loss=0.9627 | train=50.84% | test=80.40% | best=82.85% | 92.1s
# Epoch  36/100 | loss=0.9340 | train=50.16% | test=80.14% | best=82.85% | 92.1s
# Epoch  37/100 | loss=0.9288 | train=48.39% | test=81.50% | best=82.85% | 92.1s
# Epoch  38/100 | loss=0.8628 | train=49.97% | test=80.53% | best=82.85% | 92.1s
# Epoch  39/100 | loss=0.9367 | train=49.82% | test=80.72% | best=82.85% | 92.1s
# Epoch  40/100 | loss=0.9718 | train=47.52% | test=81.50% | best=82.85% | 92.1s
# Epoch  41/100 | loss=0.9461 | train=48.91% | test=80.46% | best=82.85% | 92.1s
# Epoch  42/100 | loss=0.8889 | train=50.54% | test=81.75% | best=82.85% | 92.1s
# Epoch  43/100 | loss=0.8472 | train=47.53% | test=81.88% | best=82.85% | 92.1s
# Epoch  44/100 | loss=0.8814 | train=50.05% | test=81.11% | best=82.85% | 92.1s
# Epoch  45/100 | loss=0.9290 | train=50.66% | test=80.53% | best=82.85% | 92.0s
# Epoch  46/100 | loss=0.9257 | train=43.35% | test=80.92% | best=82.85% | 92.0s
# Epoch  47/100 | loss=0.9067 | train=53.72% | test=81.37% | best=82.85% | 92.0s
# Epoch  48/100 | loss=0.8568 | train=51.98% | test=80.34% | best=82.85% | 92.0s
# Epoch  49/100 | loss=0.8434 | train=50.03% | test=81.37% | best=82.85% | 92.1s
# Epoch  50/100 | loss=0.8236 | train=47.32% | test=81.43% | best=82.85% | 92.1s
# Epoch  51/100 | loss=0.8904 | train=49.77% | test=81.95% | best=82.85% | 92.1s
# Epoch  52/100 | loss=0.8492 | train=49.02% | test=81.75% | best=82.85% | 92.1s
# Epoch  53/100 | loss=0.8654 | train=46.35% | test=82.08% | best=82.85% | 92.1s
# Epoch  54/100 | loss=0.8875 | train=49.92% | test=81.69% | best=82.85% | 92.1s
# Epoch  55/100 | loss=0.9131 | train=48.91% | test=82.21% | best=82.85% | 92.1s
# Epoch  56/100 | loss=0.8536 | train=51.51% | test=80.92% | best=82.85% | 92.1s
# Epoch  57/100 | loss=0.8719 | train=50.14% | test=82.33% | best=82.85% | 92.1s
# Epoch  58/100 | loss=0.8435 | train=51.36% | test=78.79% | best=82.85% | 92.1s
# Epoch  59/100 | loss=0.8688 | train=46.37% | test=80.53% | best=82.85% | 92.1s
# Epoch  60/100 | loss=0.8303 | train=55.48% | test=80.27% | best=82.85% | 92.1s
# Epoch  61/100 | loss=0.8667 | train=48.58% | test=80.92% | best=82.85% | 92.1s
# Epoch  62/100 | loss=0.7947 | train=53.34% | test=82.14% | best=82.85% | 92.1s
# Epoch  63/100 | loss=0.7983 | train=53.01% | test=81.62% | best=82.85% | 92.1s
# Epoch  64/100 | loss=0.8580 | train=52.40% | test=81.62% | best=82.85% | 92.1s
# Epoch  65/100 | loss=0.8012 | train=46.03% | test=80.79% | best=82.85% | 92.0s
# Epoch  66/100 | loss=0.8543 | train=50.64% | test=80.79% | best=82.85% | 92.0s
# Epoch  67/100 | loss=0.9269 | train=49.75% | test=80.59% | best=82.85% | 92.0s
# Epoch  68/100 | loss=0.7736 | train=53.63% | test=80.98% | best=82.85% | 92.1s
# Epoch  69/100 | loss=0.8122 | train=52.34% | test=81.24% | best=82.85% | 92.1s
# Epoch  70/100 | loss=0.8668 | train=48.40% | test=82.53% | best=82.85% | 92.1s
# Epoch  71/100 | loss=0.8200 | train=50.07% | test=82.14% | best=82.85% | 92.1s
# Epoch  72/100 | loss=0.8360 | train=48.48% | test=80.85% | best=82.85% | 92.0s
# Epoch  73/100 | loss=0.8326 | train=50.48% | test=81.37% | best=82.85% | 94.1s
# Epoch  74/100 | loss=0.7217 | train=50.71% | test=81.11% | best=82.85% | 92.2s
# Epoch  75/100 | loss=0.7819 | train=54.34% | test=81.17% | best=82.85% | 92.2s
# Epoch  76/100 | loss=0.7998 | train=50.84% | test=81.11% | best=82.85% | 92.2s
# Epoch  77/100 | loss=0.8510 | train=52.87% | test=81.75% | best=82.85% | 92.2s
# Epoch  78/100 | loss=0.7878 | train=47.47% | test=81.75% | best=82.85% | 92.1s
# Epoch  79/100 | loss=0.8618 | train=46.63% | test=82.14% | best=82.85% | 92.1s
# Epoch  80/100 | loss=0.7571 | train=51.05% | test=81.30% | best=82.85% | 92.1s
# Epoch  81/100 | loss=0.8407 | train=47.29% | test=81.62% | best=82.85% | 92.1s
# Epoch  82/100 | loss=0.7984 | train=51.72% | test=81.50% | best=82.85% | 92.1s
# Epoch  83/100 | loss=0.8163 | train=48.59% | test=81.50% | best=82.85% | 92.1s
# Epoch  84/100 | loss=0.8319 | train=49.44% | test=81.37% | best=82.85% | 92.0s
# Epoch  85/100 | loss=0.7993 | train=48.70% | test=79.24% | best=82.85% | 92.0s
# Epoch  86/100 | loss=0.8446 | train=51.28% | test=81.75% | best=82.85% | 92.1s
# Epoch  87/100 | loss=0.8272 | train=50.50% | test=82.66% | best=82.85% | 92.0s
# Epoch  88/100 | loss=0.7310 | train=48.90% | test=81.75% | best=82.85% | 92.0s
# Epoch  89/100 | loss=0.7657 | train=51.19% | test=81.24% | best=82.85% | 92.0s
# Epoch  90/100 | loss=0.7669 | train=48.94% | test=81.30% | best=82.85% | 92.0s
# Epoch  91/100 | loss=0.7443 | train=53.10% | test=80.34% | best=82.85% | 92.1s
# Epoch  92/100 | loss=0.8257 | train=50.64% | test=81.04% | best=82.85% | 92.1s
# Epoch  93/100 | loss=0.7631 | train=53.02% | test=81.17% | best=82.85% | 92.1s
# Epoch  94/100 | loss=0.8275 | train=51.58% | test=80.01% | best=82.85% | 92.1s
# Epoch  95/100 | loss=0.8281 | train=50.26% | test=80.92% | best=82.85% | 92.1s
# Epoch  96/100 | loss=0.8302 | train=53.41% | test=81.69% | best=82.85% | 92.1s
# Epoch  97/100 | loss=0.7590 | train=52.00% | test=81.69% | best=82.85% | 92.1s
# Epoch  98/100 | loss=0.7768 | train=48.41% | test=80.59% | best=82.85% | 92.1s
# Epoch  99/100 | loss=0.7845 | train=49.35% | test=82.40% | best=82.85% | 92.1s
# Epoch 100/100 | loss=0.7541 | train=54.12% | test=80.92% | best=82.85% | 92.1s

# %% [markdown]
# # 6: Training Curves

# %%
# Plot training curves: loss, train accuracy, test accuracy
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
ep = range(1, EPOCHS + 1)

axes[0].plot(ep, train_losses, "#1565C0", lw=2)
axes[0].set(title="Training Loss", xlabel="Epoch", ylabel="Loss")
axes[0].grid(alpha=0.3)

axes[1].plot(ep, train_accs, "#2E7D32", lw=2)
axes[1].set(title="Train Accuracy", xlabel="Epoch", ylabel="Accuracy (%)")
axes[1].grid(alpha=0.3)

axes[2].plot(ep, test_accs, "#E65100", lw=2)
axes[2].axhline(max(test_accs), color="red", ls="--", label=f"Best={max(test_accs):.2f}%")
axes[2].set(title="Test Accuracy", xlabel="Epoch", ylabel="Accuracy (%)")
axes[2].legend()
axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 7: Final Evaluation & Confusion Matrix

# %%
# Load the best  weights 
WEIGHTS_PATH = root / "Models/weights/convnext_baseline_224.pth"

model.load_state_dict(torch.load(WEIGHTS_PATH, map_location=DEVICE))
model.to(DEVICE)
model.eval() 

# run full-test inference
all_preds, all_labels = [], []

# inference loop for classification evaluation.
with torch.no_grad():                                   
    for imgs, lbls in test_loader:                      
        preds = model(imgs.to(DEVICE)).argmax(1).cpu()   
        all_preds.extend(preds.numpy())                 
        all_labels.extend(lbls.numpy())                 

y_pred = np.array(all_preds)    
y_true = np.array(all_labels)  

# calculate evaluation metrics
acc  = (y_pred == y_true).mean() * 100
macro_f1   = f1_score(y_true, y_pred, average="macro") * 100
weighted_f1 = f1_score(y_true, y_pred, average="weighted") * 100
prec = precision_score(y_true, y_pred, average="macro") * 100
rec  = recall_score(y_true, y_pred, average="macro") * 100

# print to screen.
print("="*50)
print("ConvNeXt Baseline (224px): Final Metrics")
print("="*50)
print(f"Accuracy     : {acc:.2f}%")
print(f"Macro F1     : {macro_f1:.2f}%")
print(f"Weighted F1  : {weighted_f1:.2f}%")
print(f"Precision    : {prec:.2f}%")
print(f"Recall       : {rec:.2f}%")
print("="*50)

# confusion matrix (normalised)
cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

# plot the confusion matrix
fig, ax = plt.subplots(figsize=(18, 15))
sns.heatmap(
    cm_norm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES,
    linewidths=0.3
)
ax.set_title(f"ConvNeXt Baseline (224px): Confusion Matrix\nAcc={acc:.2f}%", fontsize=14)
ax.set_xlabel("Predicted")
ax.set_ylabel("True")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# ==================================================
# ConvNeXt Baseline (224px): Final Metrics
# ==================================================
# Accuracy     : 82.85%
# Macro F1     : 80.87%
# Weighted F1  : 82.74%
# Precision    : 81.80%
# Recall       : 81.30%
# ==================================================
